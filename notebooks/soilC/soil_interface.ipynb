# %% [markdown]
# ## Import libraries
# Add directory with the CIBUSmod modules to path to be able to import

# %%
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(),'..'))

# %% [markdown]
# Import CIBUSmod and packages for handling data and plotting

# %%
import CIBUSmod as cm
import CIBUSmod.utils.plot as plot

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Instatiate Session

# %%
session = cm.Session(
    name = 'no_cows',
    data_path = '../data'
)
# Out:
#   Cell In[15], line 1
#     session = cm.Session(
#                         ^
# SyntaxError: '(' was never closed

# %%
icbm
# Out:
#                                                         area_ha  harvest_kgdm  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020  3316.116761  2.127790e+07
#                                               2021  3305.945435  2.121263e+07
#                                               2022  3295.774109  2.114737e+07
#                                               2023  3285.602783  2.108210e+07
#                                               2024  3275.431457  2.101684e+07
# ...                                                         ...           ...
#             Sweet lupin   organic      913    2046     0.000028           NaN
#                                               2047     0.000029           NaN
#                                               2048     0.000030           NaN
#                                               2049     0.000031           NaN
#                                               2050     0.000032           NaN
#
#                                                     crop_residues_harvest_kgdm  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020                1.031696e+07
#                                               2021                1.012782e+07
#                                               2022                9.938679e+06
#                                               2023                9.749538e+06
#                                               2024                9.560398e+06
# ...                                                                        ...
#             Sweet lupin   organic      913    2046                         NaN
#                                               2047                         NaN
#                                               2048                         NaN
#                                               2049                         NaN
#                                               2050                         NaN
#
#                                                     manure_cattle_kgC  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020      164692.116296
#                                               2021      159046.212557
#                                               2022      153400.308817
#                                               2023      147754.405077
#                                               2024      142108.501338
# ...                                                               ...
#             Sweet lupin   organic      913    2046           0.000000
#                                               2047           0.000000
#                                               2048           0.000000
#                                               2049           0.000000
#                                               2050           0.000000
#
#                                                     manure_horses_kgC  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020        6422.869981
#                                               2021        6407.525357
#                                               2022        6392.180734
#                                               2023        6376.836110
#                                               2024        6361.491486
# ...                                                               ...
#             Sweet lupin   organic      913    2046           0.000000
#                                               2047           0.000000
#                                               2048           0.000000
#                                               2049           0.000000
#                                               2050           0.000000
#
#                                                     manure_pigs_kgC  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020    419914.221812
#                                               2021    419642.604551
#                                               2022    419370.987289
#                                               2023    419099.370028
#                                               2024    418827.752767
# ...                                                             ...
#             Sweet lupin   organic      913    2046         0.000000
#                                               2047         0.000000
#                                               2048         0.000000
#                                               2049         0.000000
#                                               2050         0.000000
#
#                                                     manure_poultry_kgC  \
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020        3.599071e+06
#                                               2021        3.608158e+06
#                                               2022        3.617245e+06
#                                               2023        3.626332e+06
#                                               2024        3.635419e+06
# ...                                                                ...
#             Sweet lupin   organic      913    2046        0.000000e+00
#                                               2047        0.000000e+00
#                                               2048        0.000000e+00
#                                               2049        0.000000e+00
#                                               2050        0.000000e+00
#
#                                                     manure_sheep_kgC
# scn         crop          prod_system  region year
# FAI_no_cows Wheat, winter conventional 1011   2020       7672.955011
#                                               2021       7678.026938
#                                               2022       7683.098866
#                                               2023       7688.170793
#                                               2024       7693.242720
# ...                                                              ...
#             Sweet lupin   organic      913    2046          0.000000
#                                               2047          0.000000
#                                               2048          0.000000
#                                               2049          0.000000
#                                               2050          0.000000
#
# [308884 rows x 8 columns]

# %% [markdown]
# ## Using the output from the session module to calculate soil carbon stock changes
# This saves the `session` data in csv and json files in the location set by `temp_path`.
# These can be reimported in the `run_soil` notebook to calculate soc timeseries.

# %%
from CIBUSmod.utils.output_data_manip_db import to_ICBM
from CIBUSmod.soil_modules.soil_utils import to_csv_preserved
from CIBUSmod.soil_modules.soil_utils import soil_temp_path
from CIBUSmod.soil_modules.soil_utils import save_data
icbm = to_ICBM(session)
scenario = icbm.index.get_level_values('scn').unique()[0]
to_csv_preserved(icbm, f'session_{scenario}', save_path=soil_temp_path)
save_data(session.name, f'session_{scenario}_name', soil_temp_path)
# Out:
# C:\Users\ÄGARE\Documents\PycharmProjects\CIBUSmod\notebooks\..\CIBUSmod\utils\output_data_manip_db.py:196: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(['crop','prod_system','region'])
# C:\Users\ÄGARE\Documents\PycharmProjects\CIBUSmod\notebooks\..\CIBUSmod\utils\output_data_manip_db.py:196: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(['crop','prod_system','region'])
# C:\Users\ÄGARE\Documents\PycharmProjects\CIBUSmod\notebooks\..\CIBUSmod\utils\output_data_manip_db.py:196: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(['crop','prod_system','region'])
# C:\Users\ÄGARE\Documents\PycharmProjects\CIBUSmod\notebooks\..\CIBUSmod\utils\output_data_manip_db.py:196: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(['crop','prod_system','region'])

# %% [markdown]
# ## The cells below can be used to plot, summarise and save icbm (dataframe) data.
# They are not used for any calculations

# %%
for scn in session.scenarios():
    print(scn)
    print('-'*len(scn))

    fig, axs = plt.subplots(1,4, figsize=(16,5), dpi=80)

    ax=axs[0]
    (icbm.loc[scn].groupby(['year']).sum()['harvest_kgdm']/1000000).plot(kind='area', color='grey', ax=ax)
    start, end = ax.get_xlim()
    ax.set_title('harvest (1000 tonnes DM)')
    
    ax=axs[1]
    (icbm.loc[scn].groupby(['year']).sum()['crop_residues_harvest_kgdm']/1000000).plot(kind='area', color='grey', ax=ax)
    start, end = ax.get_xlim()
    ax.set_title('crop residues harvest (1000 tonnes DM)')
    
    ax=axs[2]
    (icbm.loc[scn].groupby(['year']).sum()['area_ha']/1000).plot(kind='area', color='grey', ax=ax)
    start, end = ax.get_xlim()
    ax.set_title('area (1000 ha)')
    
    ax=axs[3]
    (icbm.loc[scn].groupby(['year']).sum().loc[:,'manure_cattle_kgC':]/1000000).plot(kind='area', color=['#eeeeee','#cccccc','#aaaaaa','#888888'], stacked=True, ax=ax)
    start, end = ax.get_xlim()
    ax.set_title('manure (1000 tonnes C)')
    plt.show()

# %%
# Write csv-files
from datetime import date
for scn in session.scenarios():
    icbm.loc[[scn]].to_csv(f'{scn}_to_ICBM_{date.today().strftime("%y%m%d")}.csv')

# %%
icbm.index.names, icbm.columns, str(icbm.index.get_level_values('scn').unique()[0])
